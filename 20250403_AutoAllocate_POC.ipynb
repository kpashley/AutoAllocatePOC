# %%
import pandas as pd
import os
import datetime

# %%
# Load preferred sailings per month (First Data)
preferred_sailing_df = pd.read_excel('ShipsPerRegion_V2.xlsx', sheet_name = 'Main Data')

# %%
preferred_sailing_df.head()
# Out:
#      LOB  Prefered Sailing pm     Starting Region       Ending Region  \
# 0    BAJ                  1.0       South America                Asia
# 1  ESA-S                  1.0  Continental Europe         Middle East
# 2  EXP-A                  3.0  Continental Europe         Middle East
# 3    GIP                  1.0       North America         Middle East
# 4  GIR-C                  3.0         Middle East  Continental Europe
#
#    Avg Voyage days  Med Voyage days  Min Voyage days  Max Voyage days  \
# 0        57.081081             58.0               31               81
# 1        56.666667             59.0               27               86
# 2        42.329897             42.0               14               73
# 3        75.641026             77.0               31              115
# 4        69.835821             67.0               37              114
#
#    Distinct_Voyage_Count  Voyage Frequency per month  \
# 0                     37                    0.525568
# 1                     15                    0.529412
# 2                     97                    0.708719
# 3                     39                    0.396610
# 4                     67                    0.429579
#
#    Total Ships Needed per Route  Total Ships Needed per Route (Round)  \
# 0                      1.902703                                   2.0
# 1                      1.888889                                   2.0
# 2                      4.232990                                   4.0
# 3                      2.521368                                   2.5
# 4                      6.983582                                   7.0
#
#               Acceptable classes  Acceptable ships
# 0          ['J30', 'J32', 'J33']               NaN
# 1          ['C33', 'J32', 'C30']               NaN
# 2  ['C33', 'N37B', 'N43', 'J30']               NaN
# 3  ['J33', 'N37A', 'N43', 'C33']               NaN
# 4         ['C33', 'N37B', 'N43']               NaN

# %%
# Load actual ships and their current regions (Second Data from Dim Voyage)
ship_availability_df = pd.read_excel('ShipsPerRegion_V2.xlsx', sheet_name = 'Commence Region') 
# Filter for MonthYear = '2025-01'
ship_availability_df = ship_availability_df[ship_availability_df['MonthYear'] == '2025-01']

# %%
ship_availability_df.head()
# Out:
#    vesselcode Class MonthYear lineofbusinesscode CommencingPort  \
# 0       BBRIS   C25   2025-01                TAE        HOUSTON
# 4       BCASA   C25   2025-01         AMER TRAMP  SANTA ROSALIA
# 7       BHSTN   C25   2025-01                AAG    MAP TA PHUT
# 11      BNOLA   C25   2025-01               PACS          GEBZE
# 18      BOOSL   J32   2025-01              GIR-U       FUJAIRAH
#
#            region   MappedRegion
# 0            USWG  North America
# 4          MEXICO  South America
# 7        FAR EAST           Asia
# 11  MEDITERRANEAN    Middle East
# 18   PERSIAN GULF    Middle East

# %%
import pandas as pd

seen_ships = set()  # Track all ships ever seen

def allocate_ships(preferred_sailing_df, ship_availability_df, months):
    ship_status = {}  # Stores latest end regions and return months
    unassigned_ships = set()  # Ships not allocated in previous months
    all_allocations = []  # Store final allocation output

    for month in months:
        print(f"\n🔹 Allocating ships for {month}...")

        # 🚢 **Step 1: Refresh Demand**
        lob_demand = preferred_sailing_df.set_index(['LOB', 'Starting Region', 'Ending Region'])['Prefered Sailing pm'].to_dict()
        print(f"🔍 Initial Demand: {lob_demand}")

        # 🚢 **Step 2: Get Available Ships for the Month**
        available_ships_now = set(ship_availability_df[ship_availability_df['MonthYear'] == month]['vesselcode'])
        new_ships = available_ships_now - seen_ships  # Ships appearing for the first time
        seen_ships.update(available_ships_now)

        # Identify ships returning from previous assignments
        returned_ships = {ship for ship, details in ship_status.items() if details['return_month'] == month}

        # Combine Available Ships
        available_ships = new_ships | returned_ships | unassigned_ships

        # Remove Busy Ships (those returning later)
        busy_ships = {ship for ship, details in ship_status.items() if details['return_month'] > month}
        available_ships -= busy_ships

        # Convert to List with Correct Start Regions
        available_ships_list = []
        for ship in available_ships:
            if ship in ship_status:  # If previously assigned, start from its last ending region
                start_region = ship_status[ship]['end_region']
            else:  # If new ship, get from availability data
                start_region = ship_availability_df.loc[ship_availability_df['vesselcode'] == ship, 'MappedRegion'].values[0]
            available_ships_list.append((ship, start_region))

        print(f"🚢 Available Ships for {month}: {available_ships_list}")

        # 🚢 **Step 3: Assign Ships Based on Demand**
        allocated_ships = []
        remaining_unassigned_ships = set(ship for ship, _ in available_ships_list)
        sorted_lob_keys = sorted(lob_demand.keys(), key=lambda k: lob_demand[k], reverse=True)

        for ship_name, ship_region in available_ships_list:
            assigned_lob = next((key for key in sorted_lob_keys if key[1] == ship_region and lob_demand.get(key, 0) > 0), None)
            
            if assigned_lob:
                allocated_ships.append({
                    'Month': month,
                    'vesselcode': ship_name,
                    'Assigned_LOB': assigned_lob[0],
                    'Starting Region': assigned_lob[1],
                    'Ending Region': assigned_lob[2]
                })
                lob_demand[assigned_lob] -= 1  # Reduce demand
                remaining_unassigned_ships.discard(ship_name)

                # Get voyage duration and set new return month
                voyage_days = preferred_sailing_df[
                    (preferred_sailing_df['LOB'] == assigned_lob[0]) & 
                    (preferred_sailing_df['Starting Region'] == assigned_lob[1]) & 
                    (preferred_sailing_df['Ending Region'] == assigned_lob[2])
                ]['Avg Voyage days']

                avg_voyage_days = int(voyage_days.values[0]) if not voyage_days.empty else 60  # Default to 60 days if missing

                next_available_month_index = min(months.index(month) + (avg_voyage_days // 30), len(months) - 1)
                next_available_month = months[next_available_month_index]

                # Update ship's last known region and return time
                ship_status[ship_name] = {'end_region': assigned_lob[2], 'return_month': next_available_month}

        # 🚢 **Step 4: Update Unassigned Ships List**
        unassigned_ships = remaining_unassigned_ships  

        # 🚢 **Step 5: Print Summary**
        print(f"✅ Total available ships in {month}: {len(available_ships)}")
        print(f"🚢 Allocated Ships in {month}: {len(allocated_ships)}")
        print(f"❌ Unassigned Ships in {month}: {len(unassigned_ships)}")
        print(f"📉 LOB demand remaining after allocation in {month}: {sum(lob_demand.values())}")

        all_allocations.extend(allocated_ships)

    allocation_df = pd.DataFrame(all_allocations)
    print("\n📝 Final Allocation Output:")
    print(allocation_df)
    return allocation_df

# %%
months = ['2025-01', '2025-02', '2025-03', '2025-04', '2025-05', '2025-06']
allocation_result = allocate_ships(preferred_sailing_df, ship_availability_df, months)
# Generate timestamp for unique filenames
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# Save the file with a timestamp
filename = f"Ship_Allocation_Till_June_{timestamp}.xlsx"
allocation_result.to_excel(filename, index=False)

print(f"✅ Allocation saved as: {filename}")
# Out:
# 🔹 Allocating ships for 2025-01...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-01: [('SPERS', 'Asia'), ('SSTRE', 'North America'), ('SKIRI', 'North America'), ('SSAGA', 'Asia'), ('SFLA', 'South America'), ('SBISM', 'North America'), ('BSHNG', 'North America'), ('SDUGO', 'North America'), ('SSPAN', 'North America'), ('SBOBC', 'North America'), ('BHSTN', 'Asia'), ('SINTG', 'Asia'), ('SLIND', 'Asia'), ('SILEX', 'North America'), ('SEFFO', 'Continental Europe'), ('SCEDA', 'Asia'), ('SVISI', 'South America'), ('SCOMM', 'Asia'), ('SEND', 'Continental Europe'), ('SLOYA', 'North America'), ('BCASA', 'South America'), ('SINSP', 'Continental Europe'), ('SACHI', 'North America'), ('SSEA', 'North America'), ('BRDAM', 'South America'), ('SOCEL', 'South America'), ('SLERK', 'Asia'), ('BBRIS', 'North America'), ('SBTLA', 'North America'), ('BNOLA', 'Middle East'), ('SBAS', 'Continental Europe'), ('SVIRT', 'Middle East'), ('SINVE', 'North America'), ('SFLBO', 'Continental Europe'), ('SPALM', 'Asia'), ('STREN', 'Asia'), ('SSPRA', 'North America'), ('SSURF', 'Asia'), ('SEXCL', 'North America'), ('BOOSL', 'Middle East')]
# ✅ Total available ships in 2025-01: 40
# 🚢 Allocated Ships in 2025-01: 27
# ❌ Unassigned Ships in 2025-01: 13
# 📉 LOB demand remaining after allocation in 2025-01: 5.5
#
# 🔹 Allocating ships for 2025-02...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-02: [('SVISI', 'North America'), ('SEND', 'Middle East'), ('SLOYA', 'Mediterranean'), ('BCASA', 'Asia'), ('SINSP', 'Middle East'), ('SACHI', 'North America'), ('SSEA', 'North America'), ('SFLA', 'North America'), ('BRDAM', 'South America'), ('BSHNG', 'South America'), ('SEXCL', 'North America'), ('SOCEL', 'South America'), ('SLERK', 'Asia'), ('SDUGO', 'South America'), ('BBRIS', 'North America'), ('SSPAN', 'Continental Europe'), ('SBOBC', 'Continental Europe'), ('SBTLA', 'North America'), ('SBAS', 'North America'), ('SINVE', 'North America'), ('SFLBO', 'North America'), ('SPALM', 'Asia'), ('STREN', 'Asia'), ('SSPRA', 'North America'), ('SSURF', 'Asia'), ('SEFFO', 'Middle East'), ('SCEDA', 'Middle East')]
# ✅ Total available ships in 2025-02: 27
# 🚢 Allocated Ships in 2025-02: 24
# ❌ Unassigned Ships in 2025-02: 3
# 📉 LOB demand remaining after allocation in 2025-02: 8.5
#
# 🔹 Allocating ships for 2025-03...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-03: [('SPERS', 'Continental Europe'), ('SCOMM', 'South America'), ('SLOYA', 'North America'), ('SSAGA', 'Continental Europe'), ('SFLA', 'South America'), ('BRDAM', 'North America'), ('BOOSL', 'Continental Europe'), ('BSHNG', 'North America'), ('SOCEL', 'Asia'), ('SDUGO', 'South America'), ('BBRIS', 'Continental Europe'), ('SSPAN', 'Middle East'), ('SBOBC', 'Middle East'), ('SBTLA', 'Continental Europe'), ('BNOLA', 'Continental Europe'), ('SVIRT', 'Continental Europe'), ('SINVE', 'Mediterranean'), ('SFLBO', 'North America'), ('BHSTN', 'North America'), ('SINTG', 'North America'), ('SLIND', 'North America'), ('SILEX', 'Middle East'), ('SSPRA', 'North America'), ('SEXCL', 'South America'), ('SCEDA', 'Mediterranean')]
# ✅ Total available ships in 2025-03: 25
# 🚢 Allocated Ships in 2025-03: 23
# ❌ Unassigned Ships in 2025-03: 2
# 📉 LOB demand remaining after allocation in 2025-03: 9.5
#
# 🔹 Allocating ships for 2025-04...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-04: [('SPERS', 'Middle East'), ('SSTRE', 'Asia'), ('SCOMM', 'North America'), ('SEND', 'Continental Europe'), ('SKIRI', 'Asia'), ('BCASA', 'Continental Europe'), ('SINSP', 'Continental Europe'), ('SSAGA', 'Middle East'), ('SFLA', 'North America'), ('SBISM', 'Asia'), ('SEXCL', 'South America'), ('SLERK', 'Continental Europe'), ('SDUGO', 'Asia'), ('BBRIS', 'North America'), ('SBTLA', 'North America'), ('BNOLA', 'Middle East'), ('SBAS', 'Middle East'), ('SINVE', 'North America'), ('SFLBO', 'South America'), ('BHSTN', 'South America'), ('SINTG', 'Continental Europe'), ('SLIND', 'Continental Europe'), ('SPALM', 'North America'), ('SCEDA', 'Mediterranean'), ('STREN', 'North America'), ('SSURF', 'North America'), ('SEFFO', 'Continental Europe'), ('BOOSL', 'Middle East')]
# ✅ Total available ships in 2025-04: 28
# 🚢 Allocated Ships in 2025-04: 28
# ❌ Unassigned Ships in 2025-04: 0
# 📉 LOB demand remaining after allocation in 2025-04: 4.5
#
# 🔹 Allocating ships for 2025-05...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-05: [('SVISI', 'Asia'), ('SEND', 'Middle East'), ('BCASA', 'Middle East'), ('SINSP', 'Middle East'), ('SACHI', 'Asia'), ('SSEA', 'Asia'), ('SOCEL', 'Continental Europe'), ('SLERK', 'North America'), ('SSPAN', 'Continental Europe'), ('SBOBC', 'Continental Europe'), ('SBTLA', 'South America'), ('SBAS', 'Mediterranean'), ('SVIRT', 'Asia'), ('SINVE', 'South America'), ('SFLBO', 'North America'), ('BHSTN', 'Asia'), ('SLIND', 'Middle East'), ('SINTG', 'North America'), ('SILEX', 'Continental Europe'), ('SPALM', 'Continental Europe'), ('STREN', 'Continental Europe'), ('SSPRA', 'Middle East'), ('SEXCL', 'North America'), ('SCEDA', 'North America')]
# ✅ Total available ships in 2025-05: 24
# 🚢 Allocated Ships in 2025-05: 24
# ❌ Unassigned Ships in 2025-05: 0
# 📉 LOB demand remaining after allocation in 2025-05: 8.5
#
# 🔹 Allocating ships for 2025-06...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-06: [('SPERS', 'Continental Europe'), ('SSTRE', 'Continental Europe'), ('SKIRI', 'Continental Europe'), ('SSAGA', 'Continental Europe'), ('SFLA', 'Asia'), ('SBISM', 'North America'), ('BSHNG', 'Asia'), ('SDUGO', 'North America'), ('SSPAN', 'Middle East'), ('SBOBC', 'Middle East'), ('BHSTN', 'North America'), ('SINTG', 'Asia'), ('SLIND', 'Mediterranean'), ('SILEX', 'North America'), ('SEFFO', 'Asia'), ('SCEDA', 'South America'), ('SVISI', 'Continental Europe'), ('SCOMM', 'Asia'), ('SEND', 'Continental Europe'), ('SLOYA', 'Asia'), ('BCASA', 'Continental Europe'), ('SINSP', 'Continental Europe'), ('SACHI', 'Continental Europe'), ('SSEA', 'North America'), ('BRDAM', 'Asia'), ('SOCEL', 'Middle East'), ('SLERK', 'Asia'), ('BBRIS', 'Asia'), ('SBTLA', 'North America'), ('BNOLA', 'Continental Europe'), ('SBAS', 'North America'), ('SVIRT', 'North America'), ('SINVE', 'North America'), ('SFLBO', 'Asia'), ('SPALM', 'North America'), ('STREN', 'Middle East'), ('SSPRA', 'North America'), ('SSURF', 'Middle East'), ('SEXCL', 'South America'), ('BOOSL', 'North America')]
# ✅ Total available ships in 2025-06: 40
# 🚢 Allocated Ships in 2025-06: 31
# ❌ Unassigned Ships in 2025-06: 9
# 📉 LOB demand remaining after allocation in 2025-06: 1.5
#
# 📝 Final Allocation Output:
#        Month vesselcode Assigned_LOB Starting Region       Ending Region
# 0    2025-01      SPERS        HBR-C            Asia  Continental Europe
# 1    2025-01      SSTRE          TPW   North America                Asia
# 2    2025-01      SKIRI          TPW   North America                Asia
# 3    2025-01      SSAGA        HBR-C            Asia  Continental Europe
# 4    2025-01       SFLA       LAS-EN   South America       North America
# ..       ...        ...          ...             ...                 ...
# 152  2025-06      SVIRT          GIP   North America         Middle East
# 153  2025-06      SINVE        UMR-E   North America       Mediterranean
# 154  2025-06      STREN        GIR-M     Middle East       Mediterranean
# 155  2025-06      SSURF        GIR-U     Middle East       North America
# 156  2025-06      SEXCL       LAS-EN   South America       North America
#
# [157 rows x 5 columns]
# ✅ Allocation saved as: Ship_Allocation_Till_June_20250403_164445.xlsx

# %% [markdown]
# ##next steps
# 1. Compare with actuals for 3 months
# 2. Add constraints - which ships are allowed for which TL
# 3. Tonnage instead of preferred sailing per month

# %% [markdown]
# Constraints to Add to Your Greedy Algorithm
# 1️⃣ Single Assignment Per Month → Each ship can be assigned to only one LOB per month.
#
# 2️⃣ LOB Demand Limit → Do not assign more ships than the available demand for a given LOB in a month.
#
# 3️⃣ Starting Region Consistency → If a ship is reallocated, its next LOB must start from its last ending region.
#
# 4️⃣ Voyage Duration Constraint → A ship returns only after completing its voyage (based on Avg Voyage days).
#
# 5️⃣ Availability Constraint → Only ships available in the current month can be assigned.
#
# 6️⃣ Carry Forward Unassigned Ships → If a ship is unassigned in a month, it should be available in the next month.

# %%
import pandas as pd  

# Load the Excel file
acceptable_classes_df = pd.read_excel('ShipsPerRegion_V2.xlsx', sheet_name='Acceptable Classes')

# Convert "Class" column from CSV-like string to list
acceptable_classes_df['Class'] = acceptable_classes_df['Class'].astype(str).apply(lambda x: [cls.strip() for cls in x.split(",")] if "," in x else [x.strip()])

# Verify the output
print(acceptable_classes_df['Class'].head(10))
print(acceptable_classes_df['Class'].apply(type).value_counts())  # Should show <class 'list'>

acceptable_classes = acceptable_classes_df.set_index('LOB')['Class'].to_dict()
print(acceptable_classes)  # Should now work without errors
# Out:
# 0                             [C25, J25]
# 1                        [C25, J25, J30]
# 2                        [J30, J32, J33]
# 3                        [C33, J32, C30]
# 4                  [C33, N37B, N43, J30]
# 5                  [J33, N37A, N43, C33]
# 6                       [C33, N37B, N43]
# 7                  [C33, J33, N37A, N43]
# 8    [C25, C26, C30, C33, J30, J32, J33]
# 9                        [C33, C38, J25]
# Name: Class, dtype: object
# Class
# <class 'list'>    26
# Name: count, dtype: int64
# {'AAG': ['C25', 'J25'], 'AGE': ['C25', 'J25', 'J30'], 'BAJ': ['J30', 'J32', 'J33'], 'ESA-S': ['C33', 'J32', 'C30'], 'EXP-A': ['C33', 'N37B', 'N43', 'J30'], 'GIP': ['J33', 'N37A', 'N43', 'C33'], 'GIR-C': ['C33', 'N37B', 'N43'], 'GIR-U': ['C33', 'J33', 'N37A', 'N43'], 'HBR-C': ['C25', 'C26', 'C30', 'C33', 'J30', 'J32', 'J33'], 'HBR-U Panama': ['C33', 'C38', 'J25'], 'HBR-U Suez': ['C33', 'C38', 'D37', 'F37', 'J32', 'C30'], 'JAB': ['C25', 'J30'], 'JTG742': ['J32'], 'JTG743': ['N37B'], 'LAS-EN': ['C25', 'J25', 'J26'], 'LAS-ES': ['C25', 'J25', 'J26', 'J33'], 'LAS-N': ['C25'], 'PACS': ['C25', 'C26'], 'TAE': ['C33', 'D37', 'N43', 'C25'], 'TAW': ['C33', 'D37', 'J33', 'N43', 'C30'], 'TCO SNICS': ['J19', 'S22'], 'TPW': ['C30', 'C33', 'C38', 'D37', 'F37', 'J25'], 'TRAMP': ['J19', 'S22'], 'TRAMPUSACECI': ['J32', 'J33'], 'UMR-E': ['C26', 'I27', 'J23', 'J25'], 'UMR-W': ['C26', 'I27', 'J23', 'J25']}

# %%
import pandas as pd
import ast  # To safely convert string lists to Python lists

seen_ships = set()  # Track all ships ever seen

def allocate_ships(preferred_sailing_df, ship_availability_df, acceptable_classes_df, months):
    ship_status = {}  # Stores latest end regions and return months
    unassigned_ships = set()  # Ships not allocated in previous months
    all_allocations = []  # Store final allocation output


    for month in months:
        print(f"\n🔹 Allocating ships for {month}...")

        # 🚢 **Step 1: Refresh Demand**
        lob_demand = preferred_sailing_df.set_index(['LOB', 'Starting Region', 'Ending Region'])['Prefered Sailing pm'].to_dict()
        print(f"🔍 Initial Demand: {lob_demand}")

        # 🚢 **Step 2: Get Available Ships for the Month**
        available_ships_now = set(ship_availability_df[ship_availability_df['MonthYear'] == month]['vesselcode'])
        new_ships = available_ships_now - seen_ships  # Ships appearing for the first time
        seen_ships.update(available_ships_now)

        # Identify ships returning from previous assignments
        returned_ships = {ship for ship, details in ship_status.items() if details['return_month'] == month}

        # Combine Available Ships
        available_ships = new_ships | returned_ships | unassigned_ships

        # Remove Busy Ships (those returning later)
        busy_ships = {ship for ship, details in ship_status.items() if details['return_month'] > month}
        available_ships -= busy_ships

        # Convert to List with Correct Start Regions
        available_ships_list = []
        for ship in available_ships:
            if ship in ship_status:  # If previously assigned, start from its last ending region
                start_region = ship_status[ship]['end_region']
            else:  # If new ship, get from availability data
                start_region = ship_availability_df.loc[ship_availability_df['vesselcode'] == ship, 'MappedRegion'].values[0]
            available_ships_list.append((ship, start_region))

        print(f"🚢 Available Ships for {month}: {available_ships_list}")

        # 🚢 **Step 3: Assign Ships Based on Demand & Acceptable Classes**
        allocated_ships = []
        remaining_unassigned_ships = set(ship for ship, _ in available_ships_list)
        sorted_lob_keys = sorted(lob_demand.keys(), key=lambda k: lob_demand[k], reverse=True)

        for ship_name, ship_region in available_ships_list:
            # Get ship class from availability data
            ship_class = ship_availability_df.loc[ship_availability_df['vesselcode'] == ship_name, 'Class'].values[0]

            # Find an eligible LOB that matches region + ship class constraint
            assigned_lob = next((
                key for key in sorted_lob_keys 
                if key[1] == ship_region and lob_demand.get(key, 0) > 0 and
                ship_class in acceptable_classes.get(key[0], [])  # Ensure ship class is allowed
            ), None)

            if assigned_lob:
                allocated_ships.append({
                    'Month': month,
                    'vesselcode': ship_name,
                    'Assigned_LOB': assigned_lob[0],
                    'Starting Region': assigned_lob[1],
                    'Ending Region': assigned_lob[2]
                })
                lob_demand[assigned_lob] -= 1  # Reduce demand
                remaining_unassigned_ships.discard(ship_name)

                # Get voyage duration and set new return month
                voyage_days = preferred_sailing_df[
                    (preferred_sailing_df['LOB'] == assigned_lob[0]) & 
                    (preferred_sailing_df['Starting Region'] == assigned_lob[1]) & 
                    (preferred_sailing_df['Ending Region'] == assigned_lob[2])
                ]['Avg Voyage days']

                avg_voyage_days = int(voyage_days.values[0]) if not voyage_days.empty else 60  # Default to 60 days if missing

                next_available_month_index = min(months.index(month) + (avg_voyage_days // 30), len(months) - 1)
                next_available_month = months[next_available_month_index]

                # Update ship's last known region and return time
                ship_status[ship_name] = {'end_region': assigned_lob[2], 'return_month': next_available_month}

        # 🚢 **Step 4: Update Unassigned Ships List**
        unassigned_ships = remaining_unassigned_ships  

        # 🚢 **Step 5: Print Summary**
        print(f"✅ Total available ships in {month}: {len(available_ships)}")
        print(f"🚢 Allocated Ships in {month}: {len(allocated_ships)}")
        print(f"❌ Unassigned Ships in {month}: {len(unassigned_ships)}")
        print(f"📉 LOB demand remaining after allocation in {month}: {sum(lob_demand.values())}")

        all_allocations.extend(allocated_ships)

    allocation_df = pd.DataFrame(all_allocations)
    print("\n📝 Final Allocation Output:")
    print(allocation_df)  
    return allocation_df

# %%
# ✅ Corrected function call with all three required dataframes
months = ['2025-01', '2025-02', '2025-03', '2025-04', '2025-05', '2025-06']
allocation_result = allocate_ships(preferred_sailing_df, ship_availability_df, acceptable_classes_df, months)

# ✅ Generate timestamp for unique filenames
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# ✅ Save the file with a timestamp
filename = f"Ship_Allocation_Till_June_{timestamp}.xlsx"
allocation_result.to_excel(filename, index=False)

print(f"✅ Allocation saved as: {filename}")
# Out:
# 🔹 Allocating ships for 2025-01...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-01: [('SPERS', 'Asia'), ('SSTRE', 'North America'), ('SKIRI', 'North America'), ('SSAGA', 'Asia'), ('SFLA', 'South America'), ('SBISM', 'North America'), ('BSHNG', 'North America'), ('SDUGO', 'North America'), ('SSPAN', 'North America'), ('SBOBC', 'North America'), ('BHSTN', 'Asia'), ('SINTG', 'Asia'), ('SLIND', 'Asia'), ('SILEX', 'North America'), ('SEFFO', 'Continental Europe'), ('SCEDA', 'Asia'), ('SVISI', 'South America'), ('SCOMM', 'Asia'), ('SEND', 'Continental Europe'), ('SLOYA', 'North America'), ('BCASA', 'South America'), ('SINSP', 'Continental Europe'), ('SACHI', 'North America'), ('SSEA', 'North America'), ('BRDAM', 'South America'), ('SOCEL', 'South America'), ('SLERK', 'Asia'), ('BBRIS', 'North America'), ('SBTLA', 'North America'), ('BNOLA', 'Middle East'), ('SBAS', 'Continental Europe'), ('SVIRT', 'Middle East'), ('SINVE', 'North America'), ('SFLBO', 'Continental Europe'), ('SPALM', 'Asia'), ('STREN', 'Asia'), ('SSPRA', 'North America'), ('SSURF', 'Asia'), ('SEXCL', 'North America'), ('BOOSL', 'Middle East')]
# ✅ Total available ships in 2025-01: 40
# 🚢 Allocated Ships in 2025-01: 17
# ❌ Unassigned Ships in 2025-01: 23
# 📉 LOB demand remaining after allocation in 2025-01: 15.5
#
# 🔹 Allocating ships for 2025-02...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-02: [('SSTRE', 'North America'), ('SKIRI', 'North America'), ('SSAGA', 'Asia'), ('SFLA', 'South America'), ('SBISM', 'North America'), ('BSHNG', 'South America'), ('SDUGO', 'North America'), ('SSPAN', 'North America'), ('SBOBC', 'Mediterranean'), ('SILEX', 'North America'), ('SEFFO', 'Continental Europe'), ('SCEDA', 'Asia'), ('SVISI', 'South America'), ('SCOMM', 'Asia'), ('SEND', 'Continental Europe'), ('SINSP', 'North America'), ('BCASA', 'North America'), ('SSEA', 'North America'), ('BRDAM', 'North America'), ('SOCEL', 'South America'), ('BBRIS', 'South America'), ('BNOLA', 'Asia'), ('SBAS', 'Continental Europe'), ('SVIRT', 'Middle East'), ('SINVE', 'Continental Europe'), ('SFLBO', 'Middle East'), ('SPALM', 'Asia'), ('STREN', 'Asia'), ('SSPRA', 'North America'), ('SSURF', 'Asia'), ('SEXCL', 'North America'), ('BOOSL', 'Middle East')]
# ✅ Total available ships in 2025-02: 32
# 🚢 Allocated Ships in 2025-02: 12
# ❌ Unassigned Ships in 2025-02: 20
# 📉 LOB demand remaining after allocation in 2025-02: 20.5
#
# 🔹 Allocating ships for 2025-03...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-03: [('SVISI', 'South America'), ('SPERS', 'North America'), ('SSTRE', 'North America'), ('SCOMM', 'Asia'), ('SEND', 'Continental Europe'), ('BCASA', 'South America'), ('SKIRI', 'North America'), ('SSAGA', 'Asia'), ('SSEA', 'North America'), ('SFLA', 'South America'), ('BRDAM', 'South America'), ('SBISM', 'North America'), ('BOOSL', 'Middle East'), ('BSHNG', 'North America'), ('SOCEL', 'South America'), ('SLERK', 'North America'), ('SDUGO', 'North America'), ('BBRIS', 'North America'), ('SSPAN', 'North America'), ('SBOBC', 'North America'), ('SBAS', 'Continental Europe'), ('SVIRT', 'Middle East'), ('SINVE', 'North America'), ('BHSTN', 'Continental Europe'), ('SINTG', 'North America'), ('SLIND', 'Continental Europe'), ('SILEX', 'North America'), ('SSPRA', 'North America'), ('SSURF', 'Asia'), ('SEFFO', 'Continental Europe'), ('SCEDA', 'Asia')]
# ✅ Total available ships in 2025-03: 31
# 🚢 Allocated Ships in 2025-03: 10
# ❌ Unassigned Ships in 2025-03: 21
# 📉 LOB demand remaining after allocation in 2025-03: 22.5
#
# 🔹 Allocating ships for 2025-04...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-04: [('SSTRE', 'North America'), ('SKIRI', 'North America'), ('SSAGA', 'Asia'), ('SFLA', 'South America'), ('SBISM', 'North America'), ('BSHNG', 'South America'), ('SDUGO', 'North America'), ('SSPAN', 'North America'), ('SBOBC', 'Mediterranean'), ('SLIND', 'Middle East'), ('SINTG', 'North America'), ('SILEX', 'North America'), ('SEFFO', 'Continental Europe'), ('SCEDA', 'Asia'), ('SVISI', 'South America'), ('SCOMM', 'Asia'), ('SEND', 'Continental Europe'), ('SLOYA', 'Asia'), ('BCASA', 'North America'), ('SACHI', 'Asia'), ('SSEA', 'North America'), ('BRDAM', 'North America'), ('SOCEL', 'South America'), ('BBRIS', 'South America'), ('SBTLA', 'Asia'), ('BNOLA', 'Continental Europe'), ('SBAS', 'Continental Europe'), ('SVIRT', 'Middle East'), ('SFLBO', 'Continental Europe'), ('SPALM', 'Continental Europe'), ('STREN', 'North America'), ('SSPRA', 'North America'), ('SSURF', 'Asia'), ('BOOSL', 'Middle East')]
# ✅ Total available ships in 2025-04: 34
# 🚢 Allocated Ships in 2025-04: 13
# ❌ Unassigned Ships in 2025-04: 21
# 📉 LOB demand remaining after allocation in 2025-04: 19.5
#
# 🔹 Allocating ships for 2025-05...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-05: [('SVISI', 'South America'), ('SCOMM', 'Asia'), ('SSTRE', 'North America'), ('SEND', 'Continental Europe'), ('SEFFO', 'Continental Europe'), ('SINSP', 'Asia'), ('BCASA', 'South America'), ('SKIRI', 'North America'), ('SSAGA', 'Asia'), ('SSEA', 'North America'), ('SFLA', 'South America'), ('BRDAM', 'South America'), ('SBISM', 'North America'), ('BOOSL', 'Middle East'), ('BSHNG', 'North America'), ('SOCEL', 'South America'), ('SDUGO', 'North America'), ('BBRIS', 'North America'), ('SSPAN', 'North America'), ('SBOBC', 'North America'), ('SBAS', 'Continental Europe'), ('SVIRT', 'Middle East'), ('SFLBO', 'Middle East'), ('BHSTN', 'Asia'), ('SPALM', 'Middle East'), ('SILEX', 'North America'), ('STREN', 'North America'), ('SSPRA', 'North America'), ('SSURF', 'Asia'), ('SEXCL', 'Asia'), ('SCEDA', 'Asia')]
# ✅ Total available ships in 2025-05: 31
# 🚢 Allocated Ships in 2025-05: 10
# ❌ Unassigned Ships in 2025-05: 21
# 📉 LOB demand remaining after allocation in 2025-05: 22.5
#
# 🔹 Allocating ships for 2025-06...
# 🔍 Initial Demand: {('BAJ', 'South America', 'Asia'): 1.0, ('ESA-S', 'Continental Europe', 'Middle East'): 1.0, ('EXP-A', 'Continental Europe', 'Middle East'): 3.0, ('GIP', 'North America', 'Middle East'): 1.0, ('GIR-C', 'Middle East', 'Continental Europe'): 3.0, ('GIR-M', 'Middle East', 'Mediterranean'): 1.0, ('GIR-U', 'Middle East', 'North America'): 1.0, ('HBR-C', 'Asia', 'Continental Europe'): 2.0, ('HBR-U Panama', 'Asia', 'North America'): 1.0, ('HBR-U Suez', 'Asia', 'North America'): 2.0, ('JAB', 'Asia', 'South America'): 0.5, ('LAS-EN', 'South America', 'North America'): 2.0, ('LAS-ES', 'North America', 'South America'): 2.0, ('PACS', 'Continental Europe', 'Asia'): 1.0, ('TAE', 'North America', 'Continental Europe'): 2.0, ('TAW', 'Continental Europe', 'North America'): 2.0, ('TPW', 'North America', 'Asia'): 3.0, ('UMR-E', 'North America', 'Mediterranean'): 1.0, ('UMR-W', 'Mediterranean', 'North America'): 1.0, ('AAG', 'Asia', 'Middle East'): 1.0, ('AGE', 'Middle East', 'Asia'): 1.0}
# 🚢 Available Ships for 2025-06: [('SPERS', 'Asia'), ('SSTRE', 'North America'), ('SKIRI', 'North America'), ('SSAGA', 'Asia'), ('SFLA', 'South America'), ('SBISM', 'North America'), ('BSHNG', 'South America'), ('SDUGO', 'North America'), ('SSPAN', 'North America'), ('SBOBC', 'Mediterranean'), ('BHSTN', 'Continental Europe'), ('SINTG', 'Asia'), ('SLIND', 'Continental Europe'), ('SILEX', 'North America'), ('SEFFO', 'Continental Europe'), ('SCEDA', 'Asia'), ('SVISI', 'South America'), ('SCOMM', 'Asia'), ('SEND', 'Continental Europe'), ('SLOYA', 'North America'), ('BCASA', 'North America'), ('SINSP', 'North America'), ('SACHI', 'North America'), ('SSEA', 'North America'), ('BRDAM', 'North America'), ('SOCEL', 'South America'), ('SLERK', 'Asia'), ('BBRIS', 'South America'), ('SBTLA', 'North America'), ('BNOLA', 'Asia'), ('SBAS', 'Continental Europe'), ('SVIRT', 'Middle East'), ('SINVE', 'Asia'), ('SFLBO', 'Continental Europe'), ('SPALM', 'Continental Europe'), ('STREN', 'North America'), ('SSPRA', 'North America'), ('SSURF', 'Asia'), ('SEXCL', 'North America'), ('BOOSL', 'Middle East')]
# ✅ Total available ships in 2025-06: 40
# 🚢 Allocated Ships in 2025-06: 17
# ❌ Unassigned Ships in 2025-06: 23
# 📉 LOB demand remaining after allocation in 2025-06: 15.5
#
# 📝 Final Allocation Output:
#       Month vesselcode Assigned_LOB     Starting Region       Ending Region
# 0   2025-01      SPERS   HBR-U Suez                Asia       North America
# 1   2025-01      BSHNG       LAS-ES       North America       South America
# 2   2025-01      SBOBC        UMR-E       North America       Mediterranean
# 3   2025-01      BHSTN        HBR-C                Asia  Continental Europe
# 4   2025-01      SINTG   HBR-U Suez                Asia       North America
# ..      ...        ...          ...                 ...                 ...
# 74  2025-06      BBRIS       LAS-EN       South America       North America
# 75  2025-06      SBTLA        UMR-E       North America       Mediterranean
# 76  2025-06      BNOLA        HBR-C                Asia  Continental Europe
# 77  2025-06      SFLBO        EXP-A  Continental Europe         Middle East
# 78  2025-06      SPALM        EXP-A  Continental Europe         Middle East
#
# [79 rows x 5 columns]
# ✅ Allocation saved as: Ship_Allocation_Till_June_20250403_173906.xlsx
